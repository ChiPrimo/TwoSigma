# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 100)

# %%
pd.set_option('display.max_rows', 4000)

# %%
# Load merged_codes data
merged_code = pd.read_csv("merged_data_assetCodes.csv")

# %%
merged_code
# Out:
#                time assetCode                                 assetName  \
# 0        2007-02-01       A.N                  Agilent Technologies Inc
# 1        2007-02-01     AAI.N                      AirTran Holdings Inc
# 2        2007-02-01     AAP.N                    Advance Auto Parts Inc
# 3        2007-02-01    AAPL.O                                 Apple Inc
# 4        2007-02-01     ABB.N                                   ABB Ltd
# 5        2007-02-01     ABC.N                    AmerisourceBergen Corp
# 6        2007-02-01     ABD.N                          ACCO Brands Corp
# 7        2007-02-01     ABM.N                        ABM Industries Inc
# 8        2007-02-01     ABT.N                       Abbott Laboratories
# 9        2007-02-01     ABV.N   Companhia de Bebidas das Americas Ambev
# 10       2007-02-01     ABY.N                                   Unknown
# 11       2007-02-01     ACF.N      General Motors Financial Company Inc
# ...

# %%
# load merged_name data
merged_name = pd.read_csv("merged_data.csv")

# %%
merged_name
# Out:
#                time assetCode                                 assetName  \
# 0        2007-02-01       A.N                  Agilent Technologies Inc
# 1        2007-02-01     AAI.N                      AirTran Holdings Inc
# 2        2007-02-01     AAP.N                    Advance Auto Parts Inc
# 3        2007-02-01    AAPL.O                                 Apple Inc
# 4        2007-02-01     ABB.N                                   ABB Ltd
# 5        2007-02-01     ABC.N                    AmerisourceBergen Corp
# 6        2007-02-01     ABD.N                          ACCO Brands Corp
# 7        2007-02-01     ABM.N                        ABM Industries Inc
# 8        2007-02-01     ABT.N                       Abbott Laboratories
# 9        2007-02-01     ABV.N   Companhia de Bebidas das Americas Ambev
# 10       2007-02-01     ABY.N                                   Unknown
# 11       2007-02-01     ACF.N      General Motors Financial Company Inc
# ...

# %%
merged_name_nan= merged_name[pd.isnull(merged_name['sentimentNegative'])]

# %%
len(merged_name_nan)
# Out:
# 2966459
